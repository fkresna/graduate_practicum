# %%
import csv
from pymongo import MongoClient

client = MongoClient()
dw = client.ecommerceDW
# Delete Previous Date Dimension Data
dw.date.delete_many({})

# Open csv data that is genera
with open("../../rawDataSet/date_dimension.csv") as f:
	reader = csv.reader(f)
	count = 0
	dateKey = []
	fullDate = []
	dayOfWeek = []
	dayNumOfWeek = []
	dayNumOverall = []
	dayName = []
	dayAbbrev = []
	weekdayFlag = []
	weekNumInYear = []
	weekNumOverall = []
	weekBeginDate = []
	weekBeginDateKey = []
	month = []
	monthNumOverall = []
	monthName = []
	monthAbbrev = []
	quarter = []
	year = []
	yearmo = []
	fiscalMonth = []
	fiscalQuarter = []
	fiscalYear = []
	monthEndFlag = []
	sameDayYearAgo = []
	for row in reader:
		if count !=0:
			dateKey.append(row[0])
			fullDate.append(row[1])
			dayOfWeek.append(row[2])
			dayNumOfWeek.append(row[3])
			dayNumOverall.append(row[4])
			dayName.append(row[5])
			dayAbbrev.append(row[6])
			weekdayFlag.append(row[7])
			weekNumInYear.append(row[8])
			weekNumOverall.append(row[9])
			weekBeginDate.append(row[10])
			weekBeginDateKey.append(row[11])
			month.append(row[12])
			monthNumOverall.append(row[13])
			monthName.append(row[14])
			monthAbbrev.append(row[15])
			quarter.append(row[16])
			year.append(row[17])
			yearmo.append(row[18])
			fiscalMonth.append(row[19])
			fiscalQuarter.append(row[20])
			fiscalYear.append(row[21])
			monthEndFlag.append(row[22])
			sameDayYearAgo.append(row[23])
		count = count + 1

for i in range(0,len(dateKey)-1):
	jsonString = {'date_key':dateKey[i],'full_date':fullDate[i],'day_of_week':dayOfWeek[i],'day_num_of_week':dayNumOfWeek[i],'day_num_overall':dayNumOverall[i],'day_name':dayName[i],'day_abbrev':dayAbbrev[i],'weekday_flag':weekdayFlag[i],'week_num_in_year':weekNumInYear[i],'week_num_overall':weekNumOverall[i],'week_begin_date':weekBeginDate[i],'week_begin_date_key':weekBeginDateKey[i],'month':month[i],'month_num_overall':monthNumOverall[i],'month_name':monthName[i],'month_abbrev':monthAbbrev[i],'quarter':quarter[i],'year':year[i],'yearmo':yearmo[i],'fiscal_month':fiscalMonth[i],'fiscal_quarter':fiscalQuarter[i],'fiscal_year':fiscalYear[i],'month_end_flag':monthEndFlag[i],'same_day_year_ago':sameDayYearAgo[i]}
	print jsonString
	result = dw.date.insert_one(jsonString)
	print result
# Out:
# {'date_key': '20090101', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '12/29/2008', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '1', 'day_num_of_week': '1', 'full_date': '1/1/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '1', 'week_begin_date_key': '20081229', 'fiscal_month': '7', 'day_abbrev': 'Thu', 'same_day_year_ago': '1/1/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '1', 'day_name': 'Thursday', 'day_of_week': '4', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090102', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '12/29/2008', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '2', 'day_num_of_week': '2', 'full_date': '1/2/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '1', 'week_begin_date_key': '20081229', 'fiscal_month': '7', 'day_abbrev': 'Fri', 'same_day_year_ago': '1/2/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '1', 'day_name': 'Friday', 'day_of_week': '5', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090103', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '12/29/2008', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '3', 'day_num_of_week': '3', 'full_date': '1/3/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '1', 'week_begin_date_key': '20081229', 'fiscal_month': '7', 'day_abbrev': 'Sat', 'same_day_year_ago': '1/3/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '1', 'day_name': 'Saturday', 'day_of_week': '6', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090104', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '12/29/2008', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '4', 'day_num_of_week': '4', 'full_date': '1/4/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '1', 'week_begin_date_key': '20081229', 'fiscal_month': '7', 'day_abbrev': 'Sun', 'same_day_year_ago': '1/4/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '1', 'day_name': 'Sunday', 'day_of_week': '7', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090105', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/5/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '5', 'day_num_of_week': '5', 'full_date': '1/5/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '2', 'week_begin_date_key': '20090105', 'fiscal_month': '7', 'day_abbrev': 'Mon', 'same_day_year_ago': '1/5/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '2', 'day_name': 'Monday', 'day_of_week': '1', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090106', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/5/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '6', 'day_num_of_week': '6', 'full_date': '1/6/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '2', 'week_begin_date_key': '20090105', 'fiscal_month': '7', 'day_abbrev': 'Tue', 'same_day_year_ago': '1/6/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '2', 'day_name': 'Tuesday', 'day_of_week': '2', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090107', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/5/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '7', 'day_num_of_week': '7', 'full_date': '1/7/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '2', 'week_begin_date_key': '20090105', 'fiscal_month': '7', 'day_abbrev': 'Wed', 'same_day_year_ago': '1/7/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '2', 'day_name': 'Wednesday', 'day_of_week': '3', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090108', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/5/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '8', 'day_num_of_week': '8', 'full_date': '1/8/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '2', 'week_begin_date_key': '20090105', 'fiscal_month': '7', 'day_abbrev': 'Thu', 'same_day_year_ago': '1/8/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '2', 'day_name': 'Thursday', 'day_of_week': '4', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090109', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/5/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '9', 'day_num_of_week': '9', 'full_date': '1/9/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '2', 'week_begin_date_key': '20090105', 'fiscal_month': '7', 'day_abbrev': 'Fri', 'same_day_year_ago': '1/9/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '2', 'day_name': 'Friday', 'day_of_week': '5', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090110', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/5/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '10', 'day_num_of_week': '10', 'full_date': '1/10/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '2', 'week_begin_date_key': '20090105', 'fiscal_month': '7', 'day_abbrev': 'Sat', 'same_day_year_ago': '1/10/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '2', 'day_name': 'Saturday', 'day_of_week': '6', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090111', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/5/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '11', 'day_num_of_week': '11', 'full_date': '1/11/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '2', 'week_begin_date_key': '20090105', 'fiscal_month': '7', 'day_abbrev': 'Sun', 'same_day_year_ago': '1/11/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '2', 'day_name': 'Sunday', 'day_of_week': '7', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090112', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/12/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '12', 'day_num_of_week': '12', 'full_date': '1/12/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '3', 'week_begin_date_key': '20090112', 'fiscal_month': '7', 'day_abbrev': 'Mon', 'same_day_year_ago': '1/12/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '3', 'day_name': 'Monday', 'day_of_week': '1', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090113', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/12/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '13', 'day_num_of_week': '13', 'full_date': '1/13/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '3', 'week_begin_date_key': '20090112', 'fiscal_month': '7', 'day_abbrev': 'Tue', 'same_day_year_ago': '1/13/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '3', 'day_name': 'Tuesday', 'day_of_week': '2', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090114', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/12/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '14', 'day_num_of_week': '14', 'full_date': '1/14/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '3', 'week_begin_date_key': '20090112', 'fiscal_month': '7', 'day_abbrev': 'Wed', 'same_day_year_ago': '1/14/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '3', 'day_name': 'Wednesday', 'day_of_week': '3', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090115', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/12/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '15', 'day_num_of_week': '15', 'full_date': '1/15/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '3', 'week_begin_date_key': '20090112', 'fiscal_month': '7', 'day_abbrev': 'Thu', 'same_day_year_ago': '1/15/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '3', 'day_name': 'Thursday', 'day_of_week': '4', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090116', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/12/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '16', 'day_num_of_week': '16', 'full_date': '1/16/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '3', 'week_begin_date_key': '20090112', 'fiscal_month': '7', 'day_abbrev': 'Fri', 'same_day_year_ago': '1/16/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '3', 'day_name': 'Friday', 'day_of_week': '5', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090117', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/12/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '17', 'day_num_of_week': '17', 'full_date': '1/17/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '3', 'week_begin_date_key': '20090112', 'fiscal_month': '7', 'day_abbrev': 'Sat', 'same_day_year_ago': '1/17/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '3', 'day_name': 'Saturday', 'day_of_week': '6', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090118', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/12/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '18', 'day_num_of_week': '18', 'full_date': '1/18/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '3', 'week_begin_date_key': '20090112', 'fiscal_month': '7', 'day_abbrev': 'Sun', 'same_day_year_ago': '1/18/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '3', 'day_name': 'Sunday', 'day_of_week': '7', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090119', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/19/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '19', 'day_num_of_week': '19', 'full_date': '1/19/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '4', 'week_begin_date_key': '20090119', 'fiscal_month': '7', 'day_abbrev': 'Mon', 'same_day_year_ago': '1/19/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '4', 'day_name': 'Monday', 'day_of_week': '1', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090120', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/19/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '20', 'day_num_of_week': '20', 'full_date': '1/20/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '4', 'week_begin_date_key': '20090119', 'fiscal_month': '7', 'day_abbrev': 'Tue', 'same_day_year_ago': '1/20/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '4', 'day_name': 'Tuesday', 'day_of_week': '2', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090121', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/19/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '21', 'day_num_of_week': '21', 'full_date': '1/21/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '4', 'week_begin_date_key': '20090119', 'fiscal_month': '7', 'day_abbrev': 'Wed', 'same_day_year_ago': '1/21/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '4', 'day_name': 'Wednesday', 'day_of_week': '3', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090122', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/19/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '22', 'day_num_of_week': '22', 'full_date': '1/22/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '4', 'week_begin_date_key': '20090119', 'fiscal_month': '7', 'day_abbrev': 'Thu', 'same_day_year_ago': '1/22/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '4', 'day_name': 'Thursday', 'day_of_week': '4', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090123', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/19/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '23', 'day_num_of_week': '23', 'full_date': '1/23/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '4', 'week_begin_date_key': '20090119', 'fiscal_month': '7', 'day_abbrev': 'Fri', 'same_day_year_ago': '1/23/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '4', 'day_name': 'Friday', 'day_of_week': '5', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090124', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/19/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '24', 'day_num_of_week': '24', 'full_date': '1/24/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '4', 'week_begin_date_key': '20090119', 'fiscal_month': '7', 'day_abbrev': 'Sat', 'same_day_year_ago': '1/24/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '4', 'day_name': 'Saturday', 'day_of_week': '6', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090125', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/19/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '25', 'day_num_of_week': '25', 'full_date': '1/25/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '4', 'week_begin_date_key': '20090119', 'fiscal_month': '7', 'day_abbrev': 'Sun', 'same_day_year_ago': '1/25/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '4', 'day_name': 'Sunday', 'day_of_week': '7', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090126', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/26/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '26', 'day_num_of_week': '26', 'full_date': '1/26/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '5', 'week_begin_date_key': '20090126', 'fiscal_month': '7', 'day_abbrev': 'Mon', 'same_day_year_ago': '1/26/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '5', 'day_name': 'Monday', 'day_of_week': '1', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090127', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/26/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '27', 'day_num_of_week': '27', 'full_date': '1/27/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '5', 'week_begin_date_key': '20090126', 'fiscal_month': '7', 'day_abbrev': 'Tue', 'same_day_year_ago': '1/27/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '5', 'day_name': 'Tuesday', 'day_of_week': '2', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090128', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/26/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '28', 'day_num_of_week': '28', 'full_date': '1/28/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '5', 'week_begin_date_key': '20090126', 'fiscal_month': '7', 'day_abbrev': 'Wed', 'same_day_year_ago': '1/28/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '5', 'day_name': 'Wednesday', 'day_of_week': '3', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090129', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/26/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '29', 'day_num_of_week': '29', 'full_date': '1/29/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '5', 'week_begin_date_key': '20090126', 'fiscal_month': '7', 'day_abbrev': 'Thu', 'same_day_year_ago': '1/29/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '5', 'day_name': 'Thursday', 'day_of_week': '4', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090130', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/26/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '30', 'day_num_of_week': '30', 'full_date': '1/30/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '5', 'week_begin_date_key': '20090126', 'fiscal_month': '7', 'day_abbrev': 'Fri', 'same_day_year_ago': '1/30/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '5', 'day_name': 'Friday', 'day_of_week': '5', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090131', 'fiscal_year': '2009', 'month': '1', 'week_begin_date': '1/26/2009', 'year': '2009', 'month_abbrev': 'Jan', 'day_num_overall': '31', 'day_num_of_week': '31', 'full_date': '1/31/2009', 'fiscal_quarter': '3', 'month_name': 'January', 'week_num_in_year': '5', 'week_begin_date_key': '20090126', 'fiscal_month': '7', 'day_abbrev': 'Sat', 'same_day_year_ago': '1/31/2008', 'yearmo': '200901', 'month_num_overall': '1', 'week_num_overall': '5', 'day_name': 'Saturday', 'day_of_week': '6', 'weekday_flag': 'Weekend', 'month_end_flag': 'Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090201', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '1/26/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '32', 'day_num_of_week': '1', 'full_date': '2/1/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '5', 'week_begin_date_key': '20090126', 'fiscal_month': '8', 'day_abbrev': 'Sun', 'same_day_year_ago': '2/1/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '5', 'day_name': 'Sunday', 'day_of_week': '7', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090202', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/2/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '33', 'day_num_of_week': '2', 'full_date': '2/2/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '6', 'week_begin_date_key': '20090202', 'fiscal_month': '8', 'day_abbrev': 'Mon', 'same_day_year_ago': '2/2/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '6', 'day_name': 'Monday', 'day_of_week': '1', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090203', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/2/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '34', 'day_num_of_week': '3', 'full_date': '2/3/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '6', 'week_begin_date_key': '20090202', 'fiscal_month': '8', 'day_abbrev': 'Tue', 'same_day_year_ago': '2/3/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '6', 'day_name': 'Tuesday', 'day_of_week': '2', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090204', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/2/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '35', 'day_num_of_week': '4', 'full_date': '2/4/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '6', 'week_begin_date_key': '20090202', 'fiscal_month': '8', 'day_abbrev': 'Wed', 'same_day_year_ago': '2/4/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '6', 'day_name': 'Wednesday', 'day_of_week': '3', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090205', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/2/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '36', 'day_num_of_week': '5', 'full_date': '2/5/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '6', 'week_begin_date_key': '20090202', 'fiscal_month': '8', 'day_abbrev': 'Thu', 'same_day_year_ago': '2/5/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '6', 'day_name': 'Thursday', 'day_of_week': '4', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090206', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/2/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '37', 'day_num_of_week': '6', 'full_date': '2/6/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '6', 'week_begin_date_key': '20090202', 'fiscal_month': '8', 'day_abbrev': 'Fri', 'same_day_year_ago': '2/6/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '6', 'day_name': 'Friday', 'day_of_week': '5', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090207', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/2/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '38', 'day_num_of_week': '7', 'full_date': '2/7/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '6', 'week_begin_date_key': '20090202', 'fiscal_month': '8', 'day_abbrev': 'Sat', 'same_day_year_ago': '2/7/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '6', 'day_name': 'Saturday', 'day_of_week': '6', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090208', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/2/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '39', 'day_num_of_week': '8', 'full_date': '2/8/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '6', 'week_begin_date_key': '20090202', 'fiscal_month': '8', 'day_abbrev': 'Sun', 'same_day_year_ago': '2/8/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '6', 'day_name': 'Sunday', 'day_of_week': '7', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090209', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/9/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '40', 'day_num_of_week': '9', 'full_date': '2/9/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '7', 'week_begin_date_key': '20090209', 'fiscal_month': '8', 'day_abbrev': 'Mon', 'same_day_year_ago': '2/9/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '7', 'day_name': 'Monday', 'day_of_week': '1', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090210', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/9/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '41', 'day_num_of_week': '10', 'full_date': '2/10/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '7', 'week_begin_date_key': '20090209', 'fiscal_month': '8', 'day_abbrev': 'Tue', 'same_day_year_ago': '2/10/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '7', 'day_name': 'Tuesday', 'day_of_week': '2', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090211', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/9/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '42', 'day_num_of_week': '11', 'full_date': '2/11/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '7', 'week_begin_date_key': '20090209', 'fiscal_month': '8', 'day_abbrev': 'Wed', 'same_day_year_ago': '2/11/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '7', 'day_name': 'Wednesday', 'day_of_week': '3', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090212', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/9/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '43', 'day_num_of_week': '12', 'full_date': '2/12/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '7', 'week_begin_date_key': '20090209', 'fiscal_month': '8', 'day_abbrev': 'Thu', 'same_day_year_ago': '2/12/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '7', 'day_name': 'Thursday', 'day_of_week': '4', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090213', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/9/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '44', 'day_num_of_week': '13', 'full_date': '2/13/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '7', 'week_begin_date_key': '20090209', 'fiscal_month': '8', 'day_abbrev': 'Fri', 'same_day_year_ago': '2/13/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '7', 'day_name': 'Friday', 'day_of_week': '5', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090214', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/9/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '45', 'day_num_of_week': '14', 'full_date': '2/14/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '7', 'week_begin_date_key': '20090209', 'fiscal_month': '8', 'day_abbrev': 'Sat', 'same_day_year_ago': '2/14/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '7', 'day_name': 'Saturday', 'day_of_week': '6', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090215', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/9/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '46', 'day_num_of_week': '15', 'full_date': '2/15/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '7', 'week_begin_date_key': '20090209', 'fiscal_month': '8', 'day_abbrev': 'Sun', 'same_day_year_ago': '2/15/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '7', 'day_name': 'Sunday', 'day_of_week': '7', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090216', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/16/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '47', 'day_num_of_week': '16', 'full_date': '2/16/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '8', 'week_begin_date_key': '20090216', 'fiscal_month': '8', 'day_abbrev': 'Mon', 'same_day_year_ago': '2/16/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '8', 'day_name': 'Monday', 'day_of_week': '1', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090217', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/16/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '48', 'day_num_of_week': '17', 'full_date': '2/17/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '8', 'week_begin_date_key': '20090216', 'fiscal_month': '8', 'day_abbrev': 'Tue', 'same_day_year_ago': '2/17/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '8', 'day_name': 'Tuesday', 'day_of_week': '2', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090218', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/16/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '49', 'day_num_of_week': '18', 'full_date': '2/18/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '8', 'week_begin_date_key': '20090216', 'fiscal_month': '8', 'day_abbrev': 'Wed', 'same_day_year_ago': '2/18/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '8', 'day_name': 'Wednesday', 'day_of_week': '3', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090219', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/16/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '50', 'day_num_of_week': '19', 'full_date': '2/19/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '8', 'week_begin_date_key': '20090216', 'fiscal_month': '8', 'day_abbrev': 'Thu', 'same_day_year_ago': '2/19/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '8', 'day_name': 'Thursday', 'day_of_week': '4', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090220', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/16/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '51', 'day_num_of_week': '20', 'full_date': '2/20/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '8', 'week_begin_date_key': '20090216', 'fiscal_month': '8', 'day_abbrev': 'Fri', 'same_day_year_ago': '2/20/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '8', 'day_name': 'Friday', 'day_of_week': '5', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090221', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/16/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '52', 'day_num_of_week': '21', 'full_date': '2/21/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '8', 'week_begin_date_key': '20090216', 'fiscal_month': '8', 'day_abbrev': 'Sat', 'same_day_year_ago': '2/21/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '8', 'day_name': 'Saturday', 'day_of_week': '6', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090222', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/16/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '53', 'day_num_of_week': '22', 'full_date': '2/22/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '8', 'week_begin_date_key': '20090216', 'fiscal_month': '8', 'day_abbrev': 'Sun', 'same_day_year_ago': '2/22/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '8', 'day_name': 'Sunday', 'day_of_week': '7', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090223', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/23/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '54', 'day_num_of_week': '23', 'full_date': '2/23/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '9', 'week_begin_date_key': '20090223', 'fiscal_month': '8', 'day_abbrev': 'Mon', 'same_day_year_ago': '2/23/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '9', 'day_name': 'Monday', 'day_of_week': '1', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090224', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/23/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '55', 'day_num_of_week': '24', 'full_date': '2/24/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '9', 'week_begin_date_key': '20090223', 'fiscal_month': '8', 'day_abbrev': 'Tue', 'same_day_year_ago': '2/24/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '9', 'day_name': 'Tuesday', 'day_of_week': '2', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090225', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/23/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '56', 'day_num_of_week': '25', 'full_date': '2/25/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '9', 'week_begin_date_key': '20090223', 'fiscal_month': '8', 'day_abbrev': 'Wed', 'same_day_year_ago': '2/25/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '9', 'day_name': 'Wednesday', 'day_of_week': '3', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090226', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/23/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '57', 'day_num_of_week': '26', 'full_date': '2/26/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '9', 'week_begin_date_key': '20090223', 'fiscal_month': '8', 'day_abbrev': 'Thu', 'same_day_year_ago': '2/26/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '9', 'day_name': 'Thursday', 'day_of_week': '4', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090227', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/23/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '58', 'day_num_of_week': '27', 'full_date': '2/27/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '9', 'week_begin_date_key': '20090223', 'fiscal_month': '8', 'day_abbrev': 'Fri', 'same_day_year_ago': '2/27/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '9', 'day_name': 'Friday', 'day_of_week': '5', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090228', 'fiscal_year': '2009', 'month': '2', 'week_begin_date': '2/23/2009', 'year': '2009', 'month_abbrev': 'Feb', 'day_num_overall': '59', 'day_num_of_week': '28', 'full_date': '2/28/2009', 'fiscal_quarter': '3', 'month_name': 'February', 'week_num_in_year': '9', 'week_begin_date_key': '20090223', 'fiscal_month': '8', 'day_abbrev': 'Sat', 'same_day_year_ago': '2/28/2008', 'yearmo': '200902', 'month_num_overall': '2', 'week_num_overall': '9', 'day_name': 'Saturday', 'day_of_week': '6', 'weekday_flag': 'Weekend', 'month_end_flag': 'Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090301', 'fiscal_year': '2009', 'month': '3', 'week_begin_date': '2/23/2009', 'year': '2009', 'month_abbrev': 'Mar', 'day_num_overall': '60', 'day_num_of_week': '1', 'full_date': '3/1/2009', 'fiscal_quarter': '3', 'month_name': 'March', 'week_num_in_year': '9', 'week_begin_date_key': '20090223', 'fiscal_month': '9', 'day_abbrev': 'Sun', 'same_day_year_ago': '3/1/2008', 'yearmo': '200903', 'month_num_overall': '3', 'week_num_overall': '9', 'day_name': 'Sunday', 'day_of_week': '7', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090302', 'fiscal_year': '2009', 'month': '3', 'week_begin_date': '3/2/2009', 'year': '2009', 'month_abbrev': 'Mar', 'day_num_overall': '61', 'day_num_of_week': '2', 'full_date': '3/2/2009', 'fiscal_quarter': '3', 'month_name': 'March', 'week_num_in_year': '10', 'week_begin_date_key': '20090302', 'fiscal_month': '9', 'day_abbrev': 'Mon', 'same_day_year_ago': '3/2/2008', 'yearmo': '200903', 'month_num_overall': '3', 'week_num_overall': '10', 'day_name': 'Monday', 'day_of_week': '1', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090303', 'fiscal_year': '2009', 'month': '3', 'week_begin_date': '3/2/2009', 'year': '2009', 'month_abbrev': 'Mar', 'day_num_overall': '62', 'day_num_of_week': '3', 'full_date': '3/3/2009', 'fiscal_quarter': '3', 'month_name': 'March', 'week_num_in_year': '10', 'week_begin_date_key': '20090302', 'fiscal_month': '9', 'day_abbrev': 'Tue', 'same_day_year_ago': '3/3/2008', 'yearmo': '200903', 'month_num_overall': '3', 'week_num_overall': '10', 'day_name': 'Tuesday', 'day_of_week': '2', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090304', 'fiscal_year': '2009', 'month': '3', 'week_begin_date': '3/2/2009', 'year': '2009', 'month_abbrev': 'Mar', 'day_num_overall': '63', 'day_num_of_week': '4', 'full_date': '3/4/2009', 'fiscal_quarter': '3', 'month_name': 'March', 'week_num_in_year': '10', 'week_begin_date_key': '20090302', 'fiscal_month': '9', 'day_abbrev': 'Wed', 'same_day_year_ago': '3/4/2008', 'yearmo': '200903', 'month_num_overall': '3', 'week_num_overall': '10', 'day_name': 'Wednesday', 'day_of_week': '3', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090305', 'fiscal_year': '2009', 'month': '3', 'week_begin_date': '3/2/2009', 'year': '2009', 'month_abbrev': 'Mar', 'day_num_overall': '64', 'day_num_of_week': '5', 'full_date': '3/5/2009', 'fiscal_quarter': '3', 'month_name': 'March', 'week_num_in_year': '10', 'week_begin_date_key': '20090302', 'fiscal_month': '9', 'day_abbrev': 'Thu', 'same_day_year_ago': '3/5/2008', 'yearmo': '200903', 'month_num_overall': '3', 'week_num_overall': '10', 'day_name': 'Thursday', 'day_of_week': '4', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090306', 'fiscal_year': '2009', 'month': '3', 'week_begin_date': '3/2/2009', 'year': '2009', 'month_abbrev': 'Mar', 'day_num_overall': '65', 'day_num_of_week': '6', 'full_date': '3/6/2009', 'fiscal_quarter': '3', 'month_name': 'March', 'week_num_in_year': '10', 'week_begin_date_key': '20090302', 'fiscal_month': '9', 'day_abbrev': 'Fri', 'same_day_year_ago': '3/6/2008', 'yearmo': '200903', 'month_num_overall': '3', 'week_num_overall': '10', 'day_name': 'Friday', 'day_of_week': '5', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090307', 'fiscal_year': '2009', 'month': '3', 'week_begin_date': '3/2/2009', 'year': '2009', 'month_abbrev': 'Mar', 'day_num_overall': '66', 'day_num_of_week': '7', 'full_date': '3/7/2009', 'fiscal_quarter': '3', 'month_name': 'March', 'week_num_in_year': '10', 'week_begin_date_key': '20090302', 'fiscal_month': '9', 'day_abbrev': 'Sat', 'same_day_year_ago': '3/7/2008', 'yearmo': '200903', 'month_num_overall': '3', 'week_num_overall': '10', 'day_name': 'Saturday', 'day_of_week': '6', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090308', 'fiscal_year': '2009', 'month': '3', 'week_begin_date': '3/2/2009', 'year': '2009', 'month_abbrev': 'Mar', 'day_num_overall': '67', 'day_num_of_week': '8', 'full_date': '3/8/2009', 'fiscal_quarter': '3', 'month_name': 'March', 'week_num_in_year': '10', 'week_begin_date_key': '20090302', 'fiscal_month': '9', 'day_abbrev': 'Sun', 'same_day_year_ago': '3/8/2008', 'yearmo': '200903', 'month_num_overall': '3', 'week_num_overall': '10', 'day_name': 'Sunday', 'day_of_week': '7', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090309', 'fiscal_year': '2009', 'month': '3', 'week_begin_date': '3/9/2009', 'year': '2009', 'month_abbrev': 'Mar', 'day_num_overall': '68', 'day_num_of_week': '9', 'full_date': '3/9/2009', 'fiscal_quarter': '3', 'month_name': 'March', 'week_num_in_year': '11', 'week_begin_date_key': '20090309', 'fiscal_month': '9', 'day_abbrev': 'Mon', 'same_day_year_ago': '3/9/2008', 'yearmo': '200903', 'month_num_overall': '3', 'week_num_overall': '11', 'day_name': 'Monday', 'day_of_week': '1', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090310', 'fiscal_year': '2009', 'month': '3', 'week_begin_date': '3/9/2009', 'year': '2009', 'month_abbrev': 'Mar', 'day_num_overall': '69', 'day_num_of_week': '10', 'full_date': '3/10/2009', 'fiscal_quarter': '3', 'month_name': 'March', 'week_num_in_year': '11', 'week_begin_date_key': '20090309', 'fiscal_month': '9', 'day_abbrev': 'Tue', 'same_day_year_ago': '3/10/2008', 'yearmo': '200903', 'month_num_overall': '3', 'week_num_overall': '11', 'day_name': 'Tuesday', 'day_of_week': '2', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090311', 'fiscal_year': '2009', 'month': '3', 'week_begin_date': '3/9/2009', 'year': '2009', 'month_abbrev': 'Mar', 'day_num_overall': '70', 'day_num_of_week': '11', 'full_date': '3/11/2009', 'fiscal_quarter': '3', 'month_name': 'March', 'week_num_in_year': '11', 'week_begin_date_key': '20090309', 'fiscal_month': '9', 'day_abbrev': 'Wed', 'same_day_year_ago': '3/11/2008', 'yearmo': '200903', 'month_num_overall': '3', 'week_num_overall': '11', 'day_name': 'Wednesday', 'day_of_week': '3', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090312', 'fiscal_year': '2009', 'month': '3', 'week_begin_date': '3/9/2009', 'year': '2009', 'month_abbrev': 'Mar', 'day_num_overall': '71', 'day_num_of_week': '12', 'full_date': '3/12/2009', 'fiscal_quarter': '3', 'month_name': 'March', 'week_num_in_year': '11', 'week_begin_date_key': '20090309', 'fiscal_month': '9', 'day_abbrev': 'Thu', 'same_day_year_ago': '3/12/2008', 'yearmo': '200903', 'month_num_overall': '3', 'week_num_overall': '11', 'day_name': 'Thursday', 'day_of_week': '4', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090313', 'fiscal_year': '2009', 'month': '3', 'week_begin_date': '3/9/2009', 'year': '2009', 'month_abbrev': 'Mar', 'day_num_overall': '72', 'day_num_of_week': '13', 'full_date': '3/13/2009', 'fiscal_quarter': '3', 'month_name': 'March', 'week_num_in_year': '11', 'week_begin_date_key': '20090309', 'fiscal_month': '9', 'day_abbrev': 'Fri', 'same_day_year_ago': '3/13/2008', 'yearmo': '200903', 'month_num_overall': '3', 'week_num_overall': '11', 'day_name': 'Friday', 'day_of_week': '5', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090314', 'fiscal_year': '2009', 'month': '3', 'week_begin_date': '3/9/2009', 'year': '2009', 'month_abbrev': 'Mar', 'day_num_overall': '73', 'day_num_of_week': '14', 'full_date': '3/14/2009', 'fiscal_quarter': '3', 'month_name': 'March', 'week_num_in_year': '11', 'week_begin_date_key': '20090309', 'fiscal_month': '9', 'day_abbrev': 'Sat', 'same_day_year_ago': '3/14/2008', 'yearmo': '200903', 'month_num_overall': '3', 'week_num_overall': '11', 'day_name': 'Saturday', 'day_of_week': '6', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# {'date_key': '20090315', 'fiscal_year': '2009', 'month': '3', 'week_begin_date': '3/9/2009', 'year': '2009', 'month_abbrev': 'Mar', 'day_num_overall': '74', 'day_num_of_week': '15', 'full_date': '3/15/2009', 'fiscal_quarter': '3', 'month_name': 'March', 'week_num_in_year': '11', 'week_begin_date_key': '20090309', 'fiscal_month': '9', 'day_abbrev': 'Sun', 'same_day_year_ago': '3/15/2008', 'yearmo': '200903', 'month_num_overall': '3', 'week_num_overall': '11', 'day_name': 'Sunday', 'day_of_week': '7', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20090316', 'fiscal_year': '2009', 'month': '3', 'week_begin_date': '3/16/2009', 'year': '2009', 'month_abbrev': 'Mar', 'day_num_overall': '75', 'day_num_of_week': '16', 'full_date': '3/16/2009', 'fiscal_quarter': '3', 'month_name': 'March', 'week_num_in_year': '12', 'week_begin_date_key': '20090316', 'fiscal_month': '9', 'day_abbrev': 'Mon', 'same_day_year_ago': '3/16/2008', 'yearmo': '200903', 'month_num_overall': '3', 'week_num_overall': '12', 'day_name': 'Monday', 'day_of_week': '1', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '1'}
# <pymongo.results.InsertOneResult object at 0x10568e050>
# ...
# <pymongo.results.InsertOneResult object at 0x10568e410>
# {'date_key': '20170922', 'fiscal_year': '2018', 'month': '9', 'week_begin_date': '9/18/2017', 'year': '2017', 'month_abbrev': 'Sep', 'day_num_overall': '3187', 'day_num_of_week': '22', 'full_date': '9/22/2017', 'fiscal_quarter': '1', 'month_name': 'September', 'week_num_in_year': '39', 'week_begin_date_key': '20170918', 'fiscal_month': '3', 'day_abbrev': 'Fri', 'same_day_year_ago': '9/22/2016', 'yearmo': '201709', 'month_num_overall': '105', 'week_num_overall': '464', 'day_name': 'Friday', 'day_of_week': '5', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '3'}
# <pymongo.results.InsertOneResult object at 0x10568e690>
# {'date_key': '20170923', 'fiscal_year': '2018', 'month': '9', 'week_begin_date': '9/18/2017', 'year': '2017', 'month_abbrev': 'Sep', 'day_num_overall': '3188', 'day_num_of_week': '23', 'full_date': '9/23/2017', 'fiscal_quarter': '1', 'month_name': 'September', 'week_num_in_year': '39', 'week_begin_date_key': '20170918', 'fiscal_month': '3', 'day_abbrev': 'Sat', 'same_day_year_ago': '9/23/2016', 'yearmo': '201709', 'month_num_overall': '105', 'week_num_overall': '464', 'day_name': 'Saturday', 'day_of_week': '6', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '3'}
# <pymongo.results.InsertOneResult object at 0x10568e640>
# {'date_key': '20170924', 'fiscal_year': '2018', 'month': '9', 'week_begin_date': '9/18/2017', 'year': '2017', 'month_abbrev': 'Sep', 'day_num_overall': '3189', 'day_num_of_week': '24', 'full_date': '9/24/2017', 'fiscal_quarter': '1', 'month_name': 'September', 'week_num_in_year': '39', 'week_begin_date_key': '20170918', 'fiscal_month': '3', 'day_abbrev': 'Sun', 'same_day_year_ago': '9/24/2016', 'yearmo': '201709', 'month_num_overall': '105', 'week_num_overall': '464', 'day_name': 'Sunday', 'day_of_week': '7', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '3'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20170925', 'fiscal_year': '2018', 'month': '9', 'week_begin_date': '9/25/2017', 'year': '2017', 'month_abbrev': 'Sep', 'day_num_overall': '3190', 'day_num_of_week': '25', 'full_date': '9/25/2017', 'fiscal_quarter': '1', 'month_name': 'September', 'week_num_in_year': '40', 'week_begin_date_key': '20170925', 'fiscal_month': '3', 'day_abbrev': 'Mon', 'same_day_year_ago': '9/25/2016', 'yearmo': '201709', 'month_num_overall': '105', 'week_num_overall': '465', 'day_name': 'Monday', 'day_of_week': '1', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '3'}
# <pymongo.results.InsertOneResult object at 0x10568e410>
# {'date_key': '20170926', 'fiscal_year': '2018', 'month': '9', 'week_begin_date': '9/25/2017', 'year': '2017', 'month_abbrev': 'Sep', 'day_num_overall': '3191', 'day_num_of_week': '26', 'full_date': '9/26/2017', 'fiscal_quarter': '1', 'month_name': 'September', 'week_num_in_year': '40', 'week_begin_date_key': '20170925', 'fiscal_month': '3', 'day_abbrev': 'Tue', 'same_day_year_ago': '9/26/2016', 'yearmo': '201709', 'month_num_overall': '105', 'week_num_overall': '465', 'day_name': 'Tuesday', 'day_of_week': '2', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '3'}
# <pymongo.results.InsertOneResult object at 0x10568e690>
# {'date_key': '20170927', 'fiscal_year': '2018', 'month': '9', 'week_begin_date': '9/25/2017', 'year': '2017', 'month_abbrev': 'Sep', 'day_num_overall': '3192', 'day_num_of_week': '27', 'full_date': '9/27/2017', 'fiscal_quarter': '1', 'month_name': 'September', 'week_num_in_year': '40', 'week_begin_date_key': '20170925', 'fiscal_month': '3', 'day_abbrev': 'Wed', 'same_day_year_ago': '9/27/2016', 'yearmo': '201709', 'month_num_overall': '105', 'week_num_overall': '465', 'day_name': 'Wednesday', 'day_of_week': '3', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '3'}
# <pymongo.results.InsertOneResult object at 0x10568e640>
# {'date_key': '20170928', 'fiscal_year': '2018', 'month': '9', 'week_begin_date': '9/25/2017', 'year': '2017', 'month_abbrev': 'Sep', 'day_num_overall': '3193', 'day_num_of_week': '28', 'full_date': '9/28/2017', 'fiscal_quarter': '1', 'month_name': 'September', 'week_num_in_year': '40', 'week_begin_date_key': '20170925', 'fiscal_month': '3', 'day_abbrev': 'Thu', 'same_day_year_ago': '9/28/2016', 'yearmo': '201709', 'month_num_overall': '105', 'week_num_overall': '465', 'day_name': 'Thursday', 'day_of_week': '4', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '3'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20170929', 'fiscal_year': '2018', 'month': '9', 'week_begin_date': '9/25/2017', 'year': '2017', 'month_abbrev': 'Sep', 'day_num_overall': '3194', 'day_num_of_week': '29', 'full_date': '9/29/2017', 'fiscal_quarter': '1', 'month_name': 'September', 'week_num_in_year': '40', 'week_begin_date_key': '20170925', 'fiscal_month': '3', 'day_abbrev': 'Fri', 'same_day_year_ago': '9/29/2016', 'yearmo': '201709', 'month_num_overall': '105', 'week_num_overall': '465', 'day_name': 'Friday', 'day_of_week': '5', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '3'}
# <pymongo.results.InsertOneResult object at 0x10568e410>
# {'date_key': '20170930', 'fiscal_year': '2018', 'month': '9', 'week_begin_date': '9/25/2017', 'year': '2017', 'month_abbrev': 'Sep', 'day_num_overall': '3195', 'day_num_of_week': '30', 'full_date': '9/30/2017', 'fiscal_quarter': '1', 'month_name': 'September', 'week_num_in_year': '40', 'week_begin_date_key': '20170925', 'fiscal_month': '3', 'day_abbrev': 'Sat', 'same_day_year_ago': '9/30/2016', 'yearmo': '201709', 'month_num_overall': '105', 'week_num_overall': '465', 'day_name': 'Saturday', 'day_of_week': '6', 'weekday_flag': 'Weekend', 'month_end_flag': 'Month End', 'quarter': '3'}
# <pymongo.results.InsertOneResult object at 0x10568e690>
# {'date_key': '20171001', 'fiscal_year': '2018', 'month': '10', 'week_begin_date': '9/25/2017', 'year': '2017', 'month_abbrev': 'Oct', 'day_num_overall': '3196', 'day_num_of_week': '1', 'full_date': '10/1/2017', 'fiscal_quarter': '2', 'month_name': 'October', 'week_num_in_year': '40', 'week_begin_date_key': '20170925', 'fiscal_month': '4', 'day_abbrev': 'Sun', 'same_day_year_ago': '10/1/2016', 'yearmo': '201710', 'month_num_overall': '106', 'week_num_overall': '465', 'day_name': 'Sunday', 'day_of_week': '7', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '4'}
# <pymongo.results.InsertOneResult object at 0x10568e640>
# {'date_key': '20171002', 'fiscal_year': '2018', 'month': '10', 'week_begin_date': '10/2/2017', 'year': '2017', 'month_abbrev': 'Oct', 'day_num_overall': '3197', 'day_num_of_week': '2', 'full_date': '10/2/2017', 'fiscal_quarter': '2', 'month_name': 'October', 'week_num_in_year': '41', 'week_begin_date_key': '20171002', 'fiscal_month': '4', 'day_abbrev': 'Mon', 'same_day_year_ago': '10/2/2016', 'yearmo': '201710', 'month_num_overall': '106', 'week_num_overall': '466', 'day_name': 'Monday', 'day_of_week': '1', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '4'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20171003', 'fiscal_year': '2018', 'month': '10', 'week_begin_date': '10/2/2017', 'year': '2017', 'month_abbrev': 'Oct', 'day_num_overall': '3198', 'day_num_of_week': '3', 'full_date': '10/3/2017', 'fiscal_quarter': '2', 'month_name': 'October', 'week_num_in_year': '41', 'week_begin_date_key': '20171002', 'fiscal_month': '4', 'day_abbrev': 'Tue', 'same_day_year_ago': '10/3/2016', 'yearmo': '201710', 'month_num_overall': '106', 'week_num_overall': '466', 'day_name': 'Tuesday', 'day_of_week': '2', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '4'}
# <pymongo.results.InsertOneResult object at 0x10568e410>
# {'date_key': '20171004', 'fiscal_year': '2018', 'month': '10', 'week_begin_date': '10/2/2017', 'year': '2017', 'month_abbrev': 'Oct', 'day_num_overall': '3199', 'day_num_of_week': '4', 'full_date': '10/4/2017', 'fiscal_quarter': '2', 'month_name': 'October', 'week_num_in_year': '41', 'week_begin_date_key': '20171002', 'fiscal_month': '4', 'day_abbrev': 'Wed', 'same_day_year_ago': '10/4/2016', 'yearmo': '201710', 'month_num_overall': '106', 'week_num_overall': '466', 'day_name': 'Wednesday', 'day_of_week': '3', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '4'}
# <pymongo.results.InsertOneResult object at 0x10568e690>
# {'date_key': '20171005', 'fiscal_year': '2018', 'month': '10', 'week_begin_date': '10/2/2017', 'year': '2017', 'month_abbrev': 'Oct', 'day_num_overall': '3200', 'day_num_of_week': '5', 'full_date': '10/5/2017', 'fiscal_quarter': '2', 'month_name': 'October', 'week_num_in_year': '41', 'week_begin_date_key': '20171002', 'fiscal_month': '4', 'day_abbrev': 'Thu', 'same_day_year_ago': '10/5/2016', 'yearmo': '201710', 'month_num_overall': '106', 'week_num_overall': '466', 'day_name': 'Thursday', 'day_of_week': '4', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '4'}
# <pymongo.results.InsertOneResult object at 0x10568e640>
# {'date_key': '20171006', 'fiscal_year': '2018', 'month': '10', 'week_begin_date': '10/2/2017', 'year': '2017', 'month_abbrev': 'Oct', 'day_num_overall': '3201', 'day_num_of_week': '6', 'full_date': '10/6/2017', 'fiscal_quarter': '2', 'month_name': 'October', 'week_num_in_year': '41', 'week_begin_date_key': '20171002', 'fiscal_month': '4', 'day_abbrev': 'Fri', 'same_day_year_ago': '10/6/2016', 'yearmo': '201710', 'month_num_overall': '106', 'week_num_overall': '466', 'day_name': 'Friday', 'day_of_week': '5', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '4'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20171007', 'fiscal_year': '2018', 'month': '10', 'week_begin_date': '10/2/2017', 'year': '2017', 'month_abbrev': 'Oct', 'day_num_overall': '3202', 'day_num_of_week': '7', 'full_date': '10/7/2017', 'fiscal_quarter': '2', 'month_name': 'October', 'week_num_in_year': '41', 'week_begin_date_key': '20171002', 'fiscal_month': '4', 'day_abbrev': 'Sat', 'same_day_year_ago': '10/7/2016', 'yearmo': '201710', 'month_num_overall': '106', 'week_num_overall': '466', 'day_name': 'Saturday', 'day_of_week': '6', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '4'}
# <pymongo.results.InsertOneResult object at 0x10568e410>
# {'date_key': '20171008', 'fiscal_year': '2018', 'month': '10', 'week_begin_date': '10/2/2017', 'year': '2017', 'month_abbrev': 'Oct', 'day_num_overall': '3203', 'day_num_of_week': '8', 'full_date': '10/8/2017', 'fiscal_quarter': '2', 'month_name': 'October', 'week_num_in_year': '41', 'week_begin_date_key': '20171002', 'fiscal_month': '4', 'day_abbrev': 'Sun', 'same_day_year_ago': '10/8/2016', 'yearmo': '201710', 'month_num_overall': '106', 'week_num_overall': '466', 'day_name': 'Sunday', 'day_of_week': '7', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '4'}
# <pymongo.results.InsertOneResult object at 0x10568e690>
# {'date_key': '20171009', 'fiscal_year': '2018', 'month': '10', 'week_begin_date': '10/9/2017', 'year': '2017', 'month_abbrev': 'Oct', 'day_num_overall': '3204', 'day_num_of_week': '9', 'full_date': '10/9/2017', 'fiscal_quarter': '2', 'month_name': 'October', 'week_num_in_year': '42', 'week_begin_date_key': '20171009', 'fiscal_month': '4', 'day_abbrev': 'Mon', 'same_day_year_ago': '10/9/2016', 'yearmo': '201710', 'month_num_overall': '106', 'week_num_overall': '467', 'day_name': 'Monday', 'day_of_week': '1', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '4'}
# <pymongo.results.InsertOneResult object at 0x10568e640>
# {'date_key': '20171010', 'fiscal_year': '2018', 'month': '10', 'week_begin_date': '10/9/2017', 'year': '2017', 'month_abbrev': 'Oct', 'day_num_overall': '3205', 'day_num_of_week': '10', 'full_date': '10/10/2017', 'fiscal_quarter': '2', 'month_name': 'October', 'week_num_in_year': '42', 'week_begin_date_key': '20171009', 'fiscal_month': '4', 'day_abbrev': 'Tue', 'same_day_year_ago': '10/10/2016', 'yearmo': '201710', 'month_num_overall': '106', 'week_num_overall': '467', 'day_name': 'Tuesday', 'day_of_week': '2', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '4'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20171011', 'fiscal_year': '2018', 'month': '10', 'week_begin_date': '10/9/2017', 'year': '2017', 'month_abbrev': 'Oct', 'day_num_overall': '3206', 'day_num_of_week': '11', 'full_date': '10/11/2017', 'fiscal_quarter': '2', 'month_name': 'October', 'week_num_in_year': '42', 'week_begin_date_key': '20171009', 'fiscal_month': '4', 'day_abbrev': 'Wed', 'same_day_year_ago': '10/11/2016', 'yearmo': '201710', 'month_num_overall': '106', 'week_num_overall': '467', 'day_name': 'Wednesday', 'day_of_week': '3', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '4'}
# <pymongo.results.InsertOneResult object at 0x10568e410>
# {'date_key': '20171012', 'fiscal_year': '2018', 'month': '10', 'week_begin_date': '10/9/2017', 'year': '2017', 'month_abbrev': 'Oct', 'day_num_overall': '3207', 'day_num_of_week': '12', 'full_date': '10/12/2017', 'fiscal_quarter': '2', 'month_name': 'October', 'week_num_in_year': '42', 'week_begin_date_key': '20171009', 'fiscal_month': '4', 'day_abbrev': 'Thu', 'same_day_year_ago': '10/12/2016', 'yearmo': '201710', 'month_num_overall': '106', 'week_num_overall': '467', 'day_name': 'Thursday', 'day_of_week': '4', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '4'}
# <pymongo.results.InsertOneResult object at 0x10568e690>
# {'date_key': '20171013', 'fiscal_year': '2018', 'month': '10', 'week_begin_date': '10/9/2017', 'year': '2017', 'month_abbrev': 'Oct', 'day_num_overall': '3208', 'day_num_of_week': '13', 'full_date': '10/13/2017', 'fiscal_quarter': '2', 'month_name': 'October', 'week_num_in_year': '42', 'week_begin_date_key': '20171009', 'fiscal_month': '4', 'day_abbrev': 'Fri', 'same_day_year_ago': '10/13/2016', 'yearmo': '201710', 'month_num_overall': '106', 'week_num_overall': '467', 'day_name': 'Friday', 'day_of_week': '5', 'weekday_flag': 'Weekday', 'month_end_flag': 'Not Month End', 'quarter': '4'}
# <pymongo.results.InsertOneResult object at 0x10568e640>
# {'date_key': '20171014', 'fiscal_year': '2018', 'month': '10', 'week_begin_date': '10/9/2017', 'year': '2017', 'month_abbrev': 'Oct', 'day_num_overall': '3209', 'day_num_of_week': '14', 'full_date': '10/14/2017', 'fiscal_quarter': '2', 'month_name': 'October', 'week_num_in_year': '42', 'week_begin_date_key': '20171009', 'fiscal_month': '4', 'day_abbrev': 'Sat', 'same_day_year_ago': '10/14/2016', 'yearmo': '201710', 'month_num_overall': '106', 'week_num_overall': '467', 'day_name': 'Saturday', 'day_of_week': '6', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '4'}
# <pymongo.results.InsertOneResult object at 0x10568e0a0>
# {'date_key': '20171015', 'fiscal_year': '2018', 'month': '10', 'week_begin_date': '10/9/2017', 'year': '2017', 'month_abbrev': 'Oct', 'day_num_overall': '3210', 'day_num_of_week': '15', 'full_date': '10/15/2017', 'fiscal_quarter': '2', 'month_name': 'October', 'week_num_in_year': '42', 'week_begin_date_key': '20171009', 'fiscal_month': '4', 'day_abbrev': 'Sun', 'same_day_year_ago': '10/15/2016', 'yearmo': '201710', 'month_num_overall': '106', 'week_num_overall': '467', 'day_name': 'Sunday', 'day_of_week': '7', 'weekday_flag': 'Weekend', 'month_end_flag': 'Not Month End', 'quarter': '4'}
# <pymongo.results.InsertOneResult object at 0x10568e410>
